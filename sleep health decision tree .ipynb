# %%
import pandas as pd
a=pd.read_csv('/home/santhosh/Downloads/Sleep_health_and_lifestyle_dataset.csv')
a
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
a.columns[a.isna().any()]
# Out:
# Index(['Sleep Disorder'], dtype='object')

# %%
a['Sleep Disorder'] = a['Sleep Disorder'].fillna(a['Sleep Disorder'].mode()[0])
a['Sleep Disorder']
# Out:
# 0      Sleep Apnea
# 1      Sleep Apnea
# 2      Sleep Apnea
# 3      Sleep Apnea
# 4      Sleep Apnea
#           ...
# 369    Sleep Apnea
# 370    Sleep Apnea
# 371    Sleep Apnea
# 372    Sleep Apnea
# 373    Sleep Apnea
# Name: Sleep Disorder, Length: 374, dtype: object

# %%
b=pd.get_dummies(a,drop_first=True,dtype=int)
b
# Out:
#      Person ID  Age  Sleep Duration  Quality of Sleep  \
# 0            1   27             6.1                 6
# 1            2   28             6.2                 6
# 2            3   28             6.2                 6
# 3            4   28             5.9                 4
# 4            5   28             5.9                 4
# ..         ...  ...             ...               ...
# 369        370   59             8.1                 9
# 370        371   59             8.0                 9
# 371        372   59             8.1                 9
# 372        373   59             8.1                 9
# 373        374   59             8.1                 9
#
#      Physical Activity Level  Stress Level  Heart Rate  Daily Steps  \
# 0                         42             6          77         4200
# 1                         60             8          75        10000
# 2                         60             8          75        10000
# ...

# %%
x = a.drop(['Sleep Disorder', 'Person ID'], axis=1)
y = a['Sleep Disorder']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14846/4158675305.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 x_scaled = sc.fit_transform(x)
#
# ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~/anaconda3/lib/python3.13/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
#
# NameError: name 'x_scaled' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
model=DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=42)
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
x_pred=model.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x_pred=model.predict(x_train)
#
# NameError: name 'model' is not defined

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y_train
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.metrics import accuracy_score, confusion_matrix , classification_report
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 from sklearn.metrics import accuracy_score, confusion_matrix , classification_report
# ----> 2 accuracy_score(y_test,y_pred)
#
# NameError: name 'y_test' is not defined

# %%
    confusion_matrix(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 confusion_matrix(y_test,y_pred)
#
# NameError: name 'y_test' is not defined

# %%
classification_report(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 classification_report(y_test,y_pred)
#
# NameError: name 'y_test' is not defined
